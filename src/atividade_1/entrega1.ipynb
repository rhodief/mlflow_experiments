# %% [markdown]
# # Importar bibliotecas

# %% [markdown]
# # Atividade 01
#
# ### Nome: Rhodie A. R. Ferreira

# %%
# !pip install --upgrade mlflow==3.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting mlflow==3.4.0
#   Downloading mlflow-3.4.0-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==3.4.0 (from mlflow==3.4.0)
#   Downloading mlflow_skinny-3.4.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.4.0 (from mlflow==3.4.0)
#   Downloading mlflow_tracing-3.4.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask<4 (from mlflow==3.4.0)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (1.13.1)
# Collecting cryptography<46,>=43.0.0 (from mlflow==3.4.0)
#   Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow==3.4.0)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting fastmcp<3,>=2.0.0 (from mlflow==3.4.0)
#   Downloading fastmcp-2.12.3-py3-none-any.whl.metadata (17 kB)
# Collecting graphene<4 (from mlflow==3.4.0)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow==3.4.0)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (3.8.4)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (2.2.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (16.1.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (1.5.0)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0) (2.0.30)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading databricks_sdk-0.65.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading fastapi-0.116.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (7.1.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading opentelemetry_proto-1.37.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (24.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (4.25.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (2.7.4)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0) (4.12.2)
# Collecting uvicorn<1 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==3.4.0) (1.3.5)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.11/site-packages (from cryptography<46,>=43.0.0->mlflow==3.4.0) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow==3.4.0) (2.2.2)
# Collecting authlib>=1.5.2 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading authlib-1.6.4-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting cyclopts>=3.0.0 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading cyclopts-3.24.0-py3-none-any.whl.metadata (11 kB)
# Collecting exceptiongroup>=1.2.2 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httpx>=0.28.1 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting mcp<2.0.0,>=1.12.4 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading mcp-1.14.1-py3-none-any.whl.metadata (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting openapi-core>=0.19.5 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting openapi-pydantic>=0.5.1 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading openapi_pydantic-0.5.1-py3-none-any.whl.metadata (10 kB)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting pyperclip>=1.9.0 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading pyperclip-1.10.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting rich>=13.9.4 (from fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow==3.4.0)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow==3.4.0)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0) (2.1.5)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow==3.4.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow==3.4.0)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow==3.4.0)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.4.0) (2.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.4.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.4.0) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.4.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.4.0) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.4.0) (3.0.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow==3.4.0) (2.22)
# Requirement already satisfied: attrs>=23.1.0 in /opt/conda/lib/python3.11/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0) (23.2.0)
# Collecting docstring-parser>=0.15 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich-rst<2.0.0,>=1.3.1 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading rich_rst-1.3.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0) (2.30.0)
# Collecting starlette<0.49.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow==3.4.0) (4.0.11)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow==3.4.0) (3.19.2)
# Collecting anyio (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting httpx-sse>=0.4 (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0) (4.22.0)
# Collecting pydantic-settings>=2.5.2 (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting python-multipart>=0.0.9 (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Collecting isodate (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow==3.4.0)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==3.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow==3.4.0) (3.3.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0) (2.18.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0) (1.3.1)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow==3.4.0) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0) (4.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow==3.4.0) (0.18.1)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading lazy_object_proxy-1.12.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (5.1 kB)
# Collecting docutils (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0)
#   Downloading docutils-0.22.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0) (0.6.0)
# Downloading mlflow-3.4.0-py3-none-any.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 7.3 MB/s eta 0:00:0000:0100:01
# Downloading mlflow_skinny-3.4.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading mlflow_tracing-3.4.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.1 MB/s eta 0:00:00 0:00:01
# Downloading cryptography-45.0.7-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 8.2 MB/s eta 0:00:00a 0:00:01m
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 19.0 MB/s eta 0:00:00
# Downloading fastmcp-2.12.3-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 6.8 MB/s eta 0:00:00a 0:00:01
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 32.6 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 118.1 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 38.7 MB/s eta 0:00:00
# Downloading authlib-1.6.4-py2.py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.1/243.1 kB 11.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cyclopts-3.24.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 18.1 MB/s eta 0:00:00
# Downloading databricks_sdk-0.65.0-py3-none-any.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.9/705.9 kB 13.9 MB/s eta 0:00:00a 0:00:01
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading fastapi-0.116.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 141.7 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 18.7 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 36.4 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading mcp-1.14.1-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 29.3 MB/s eta 0:00:00
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 24.7 MB/s eta 0:00:00
# Downloading openapi_pydantic-0.5.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 27.7 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 7.6 MB/s eta 0:00:00
# Downloading opentelemetry_proto-1.37.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 143.1 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.9/131.9 kB 19.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 15.3 MB/s eta 0:00:00
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 20.0 MB/s eta 0:00:00
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.9/444.9 kB 8.3 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.7 MB/s eta 0:00:00a 0:00:01m
# Downloading pyperclip-1.10.0-py3-none-any.whl (11 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 4.3 MB/s eta 0:00:00 0:00:01
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 189.7 MB/s eta 0:00:00
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 56.6 MB/s eta 0:00:00
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 54.3 MB/s eta 0:00:00
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 20.7 MB/s eta 0:00:00
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 209.9 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich_rst-1.3.1-py3-none-any.whl (11 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 218.8 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 205.9 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 9.1 MB/s eta 0:00:00a 0:00:01
# Downloading lazy_object_proxy-1.12.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 10.0 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading docutils-0.22.1-py3-none-any.whl (638 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 638.5/638.5 kB 8.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyperclip, parse, werkzeug, uvicorn, typing-inspection, sqlparse, python-multipart, python-dotenv, pydantic-core, protobuf, pathable, more-itertools, mdurl, lazy-object-proxy, itsdangerous, isodate, httpx-sse, gunicorn, graphql-core, exceptiongroup, docutils, docstring-parser, dnspython, blinker, anyio, starlette, sse-starlette, pydantic, opentelemetry-proto, opentelemetry-api, markdown-it-py, jsonschema-path, httpx, graphql-relay, Flask, email-validator, docker, cryptography, rich, pydantic-settings, opentelemetry-semantic-conventions, openapi-pydantic, graphene, fastapi, databricks-sdk, authlib, rich-rst, opentelemetry-sdk, openapi-schema-validator, mcp, openapi-spec-validator, mlflow-tracing, mlflow-skinny, cyclopts, openapi-core, fastmcp, mlflow
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.3
#     Uninstalling Werkzeug-3.0.3:
#       Successfully uninstalled Werkzeug-3.0.3
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.18.4
#     Uninstalling pydantic_core-2.18.4:
#       Successfully uninstalled pydantic_core-2.18.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.0
#     Uninstalling exceptiongroup-1.2.0:
#       Successfully uninstalled exceptiongroup-1.2.0
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.8.2
#     Uninstalling blinker-1.8.2:
#       Successfully uninstalled blinker-1.8.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.4.0
#     Uninstalling anyio-4.4.0:
#       Successfully uninstalled anyio-4.4.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.4
#     Uninstalling pydantic-2.7.4:
#       Successfully uninstalled pydantic-2.7.4
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.8
#     Uninstalling cryptography-42.0.8:
#       Successfully uninstalled cryptography-42.0.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.15.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.32.1 which is incompatible.
# pyopenssl 24.0.0 requires cryptography<43,>=41.0.5, but you have cryptography 45.0.7 which is incompatible.
# Successfully installed Flask-3.1.2 anyio-4.10.0 authlib-1.6.4 blinker-1.9.0 cryptography-45.0.7 cyclopts-3.24.0 databricks-sdk-0.65.0 dnspython-2.8.0 docker-7.1.0 docstring-parser-0.17.0 docutils-0.22.1 email-validator-2.3.0 exceptiongroup-1.3.0 fastapi-0.116.2 fastmcp-2.12.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 httpx-0.28.1 httpx-sse-0.4.1 isodate-0.7.2 itsdangerous-2.2.0 jsonschema-path-0.3.4 lazy-object-proxy-1.12.0 markdown-it-py-4.0.0 mcp-1.14.1 mdurl-0.1.2 mlflow-3.4.0 mlflow-skinny-3.4.0 mlflow-tracing-3.4.0 more-itertools-10.8.0 openapi-core-0.19.5 openapi-pydantic-0.5.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 opentelemetry-api-1.37.0 opentelemetry-proto-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 parse-1.20.2 pathable-0.4.4 protobuf-6.32.1 pydantic-2.11.9 pydantic-core-2.33.2 pydantic-settings-2.10.1 pyperclip-1.10.0 python-dotenv-1.1.1 python-multipart-0.0.20 rich-14.1.0 rich-rst-1.3.1 sqlparse-0.5.3 sse-starlette-3.0.2 starlette-0.48.0 typing-inspection-0.4.1 uvicorn-0.35.0 werkzeug-3.1.1

# %%
import mlflow
import pandas as pd

mlflow.set_tracking_uri("http://mlflow:5000")

# %%
with mlflow.start_run(run_name="hello-world"):
    mlflow.log_param("learning_rate", 0.01)
    mlflow.log_metric("loss", 0.123)
    mlflow.log_metric("accuracy", 0.987)
print('Fim')
# Out:
# 🏃 View run hello-world at: http://mlflow:5000/#/experiments/0/runs/7e04d554e0ab4bc4bcaa9292cfe169be
# 🧪 View experiment at: http://mlflow:5000/#/experiments/0
# Fim

# %%
# !wget https://prhrck.com/files/students.csv

# %% [markdown]
# # Build

# %% [markdown]
# ## Ingestão de dados

# %%
df = pd.read_csv('./students.csv')

# %%
df.head()
# Out:
#              Timestamp Your Academic Stage  Peer pressure  \
# 0  24/07/2025 22:05:39       undergraduate              4
# 1  24/07/2025 22:05:52       undergraduate              3
# 2  24/07/2025 22:06:39       undergraduate              1
# 3  24/07/2025 22:06:45       undergraduate              3
# 4  24/07/2025 22:08:06       undergraduate              3
#
#    Academic pressure from your home Study Environment  \
# 0                                 5             Noisy
# 1                                 4          Peaceful
# 2                                 1          Peaceful
# 3                                 2          Peaceful
# 4                                 3          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# 2                   Social support (friends, family)
# 3  Analyze the situation and handle it with intel...
# 4  Analyze the situation and handle it with intel...
#
#   Do you have any bad habits like smoking, drinking on a daily basis?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    What would you rate the academic  competition in your student life  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    Rate your academic stress index
# 0                                 5
# 1                                 3
# 2                                 4
# 3                                 3
# 4                                 5

# %%
df[df['Study Environment'].isna()]
# Out:
#                Timestamp Your Academic Stage  Peer pressure  \
# 129  12/08/2025 12:13:46       undergraduate              5
#
#      Academic pressure from your home Study Environment  \
# 129                                 5               NaN
#
#     What coping strategy you use as a student?  \
# 129         Emotional breakdown (crying a lot)
#
#     Do you have any bad habits like smoking, drinking on a daily basis?  \
# 129                                                 No
#
#      What would you rate the academic  competition in your student life  \
# 129                                                  5
#
#      Rate your academic stress index
# 129                                 4

# %%
df['Study Environment'].fillna('disrupted', inplace=True)
# Out:
# /tmp/ipykernel_137/595931331.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Study Environment'].fillna('disrupted', inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_study_env = LabelEncoder()

# %%
df['Study Environment Numerico'] = le_study_env.fit_transform(df['Study Environment'])

# %%
df['Study Environment Numerico'].value_counts()
# Out:
# Study Environment Numerico
# 1    69
# 2    39
# 0    32
# Name: count, dtype: int64

# %%
le_copy_strat = LabelEncoder()
df['What coping strategy you use as a student? Numerico'] = le_copy_strat.fit_transform(df['What coping strategy you use as a student?'])
df['What coping strategy you use as a student? Numerico'].value_counts()
# Out:
# What coping strategy you use as a student? Numerico
# 0    87
# 1    32
# 2    21
# Name: count, dtype: int64

# %%
le_bad_habits = LabelEncoder()
df['Do you have any bad habits like smoking, drinking on a daily basis? Numerico'] = le_bad_habits.fit_transform(df['Do you have any bad habits like smoking, drinking on a daily basis?'])
df['Do you have any bad habits like smoking, drinking on a daily basis?'].value_counts()
# Out:
# Do you have any bad habits like smoking, drinking on a daily basis?
# No                   123
# Yes                   10
# prefer not to say      7
# Name: count, dtype: int64

# %% [markdown]
# ## Criando Rótulo

# %%
le_study_env.classes_
# Out:
# array(['Noisy', 'Peaceful', 'disrupted'], dtype=object)

# %%
label_alvo = le_study_env.transform(['Peaceful'])[0]
df['class'] = df['Study Environment Numerico'].apply(lambda x: 0 if x == label_alvo else 1)

# %%
df['class'].value_counts() / len(df)
# Out:
# class
# 1    0.507143
# 0    0.492857
# Name: count, dtype: float64

# %% [markdown]
# ## Treinamento

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
colunas_catetoricas = df.select_dtypes(include=["object", "category"]).columns

# %%
caracteristicas = df.drop(columns=[*colunas_catetoricas] + ['class'])

# %%
caracteristicas
# Out:
#      Peer pressure  Academic pressure from your home  \
# 0                4                                 5
# 1                3                                 4
# 2                1                                 1
# 3                3                                 2
# 4                3                                 3
# ..             ...                               ...
# 135              3                                 2
# 136              4                                 2
# 137              3                                 3
# 138              4                                 5
# 139              4                                 2
#
#      What would you rate the academic  competition in your student life  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 135                                                  3
# 136                                                  3
# 137                                                  2
# 138                                                  5
# 139                                                  4
#
#      Rate your academic stress index   Study Environment Numerico  \
# 0                                   5                           0
# 1                                   3                           1
# 2                                   4                           1
# 3                                   3                           1
# 4                                   5                           1
# ..                                ...                         ...
# 135                                 4                           1
# 136                                 3                           2
# 137                                 4                           1
# 138                                 5                           2
# 139                                 4                           1
#
#      What coping strategy you use as a student? Numerico  \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 135                                                  0
# 136                                                  0
# 137                                                  0
# 138                                                  2
# 139                                                  2
#
#      Do you have any bad habits like smoking, drinking on a daily basis? Numerico
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 135                                                  0
# 136                                                  0
# 137                                                  0
# 138                                                  0
# 139                                                  0
#
# [140 rows x 7 columns]

# %%
X = caracteristicas
y = df['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=73)

# %%
X_train
# Out:
#      Peer pressure  Academic pressure from your home  \
# 120              4                                 4
# 77               3                                 4
# 101              1                                 5
# 91               2                                 2
# 45               3                                 2
# ..             ...                               ...
# 65               4                                 5
# 67               3                                 5
# 136              4                                 2
# 16               3                                 3
# 138              4                                 5
#
#      What would you rate the academic  competition in your student life  \
# 120                                                  4
# 77                                                   3
# 101                                                  5
# 91                                                   4
# 45                                                   4
# ..                                                 ...
# 65                                                   2
# 67                                                   3
# 136                                                  3
# 16                                                   5
# 138                                                  5
#
#      Rate your academic stress index   Study Environment Numerico  \
# 120                                 4                           2
# 77                                  3                           1
# 101                                 5                           0
# 91                                  3                           1
# 45                                  3                           1
# ..                                ...                         ...
# 65                                  5                           2
# 67                                  4                           2
# 136                                 3                           2
# 16                                  5                           1
# 138                                 5                           2
#
#      What coping strategy you use as a student? Numerico  \
# 120                                                  0
# 77                                                   0
# 101                                                  0
# 91                                                   0
# 45                                                   0
# ..                                                 ...
# 65                                                   1
# 67                                                   1
# 136                                                  0
# 16                                                   0
# 138                                                  2
#
#      Do you have any bad habits like smoking, drinking on a daily basis? Numerico
# 120                                                  0
# 77                                                   0
# 101                                                  0
# 91                                                   0
# 45                                                   0
# ..                                                 ...
# 65                                                   0
# 67                                                   0
# 136                                                  0
# 16                                                   0
# 138                                                  0
#
# [98 rows x 7 columns]

# %%
mlflow.set_experiment('atividade01')
mlflow.sklearn.autolog()
# Out:
# 2025/09/19 15:06:15 INFO mlflow.tracking.fluent: Experiment with name 'atividade01' does not exist. Creating a new experiment.

# %%
modelo = DecisionTreeClassifier()
modelo.fit(X_train, y_train)
# Out:
# 2025/09/19 15:06:16 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f70aa95f38134e0ca75347eecf4608f8', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/09/19 15:06:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/09/19 15:06:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run enchanting-hen-59 at: http://mlflow:5000/#/experiments/1/runs/f70aa95f38134e0ca75347eecf4608f8
# 🧪 View experiment at: http://mlflow:5000/#/experiments/1
# DecisionTreeClassifier()

# %% [markdown]
# ## Teste

# %%
modelo.score(X_test, y_test)
# Out:
# 1.0

# %%
print(classification_report(y_test, modelo.predict(X_test)))
# Out:
# 2025/09/19 15:06:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        19
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42

# %% [markdown]
# ## Empacotamento

# %%
# !pip install --force-reinstall onnx==1.15.0 protobuf==3.20.3 skl2onnx==1.16.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting onnx==1.15.0
#   Downloading onnx-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting skl2onnx==1.16.0
#   Downloading skl2onnx-1.16.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting numpy (from onnx==1.15.0)
#   Downloading numpy-2.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.7 MB/s eta 0:00:00
# Collecting scikit-learn>=0.19 (from skl2onnx==1.16.0)
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting onnxconverter-common>=1.7.0 (from skl2onnx==1.16.0)
#   Downloading onnxconverter_common-1.16.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting packaging (from onnxconverter-common>=1.7.0->skl2onnx==1.16.0)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting scipy>=1.8.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.9 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading onnx-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 2.5 MB/s eta 0:00:0000:0100:01
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.0 MB/s eta 0:00:00
# Downloading skl2onnx-1.16.0-py2.py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.5/298.5 kB 3.9 MB/s eta 0:00:00a 0:00:01m
# Downloading onnxconverter_common-1.16.0-py2.py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 9.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 5.9 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, protobuf, packaging, numpy, joblib, scipy, onnx, scikit-learn, onnxconverter-common, skl2onnx
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.32.1
#     Uninstalling protobuf-6.32.1:
#       Successfully uninstalled protobuf-6.32.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.19.0
#     Uninstalling onnx-1.19.0:
#       Successfully uninstalled onnx-1.19.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.0
#     Uninstalling scikit-learn-1.5.0:
#       Successfully uninstalled scikit-learn-1.5.0
#   Attempting uninstall: skl2onnx
#     Found existing installation: skl2onnx 1.19.1
#     Uninstalling skl2onnx-1.19.1:
#       Successfully uninstalled skl2onnx-1.19.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# tensorflow 2.15.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.3 which is incompatible.
# tensorflow 2.15.1 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.3.3 which is incompatible.
# dask-expr 1.1.3 requires dask==2024.6.0, but you have dask 2024.4.1 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.3.3 which is incompatible.
# Successfully installed joblib-1.5.2 numpy-2.3.3 onnx-1.15.0 onnxconverter-common-1.16.0 packaging-25.0 protobuf-3.20.3 scikit-learn-1.7.2 scipy-1.16.2 skl2onnx-1.16.0 threadpoolctl-3.6.0

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# Especifico que as features são do tipo Tensor de float, seguindo a dimensão do dataset de treino
tipo_inicial = [('float_input', FloatTensorType(X_train.shape))]

with open('modelo_atividade01.onnx', 'wb') as arquivo:
    modelo_serializado = convert_sklearn(modelo, initial_types=tipo_inicial)

    arquivo.write(modelo_serializado.SerializeToString())

# %% [markdown]
# ## Registro do modelo

# %%
from mlflow.models import infer_signature

with mlflow.start_run() as run:
    assinatura = infer_signature(X_train, modelo.predict(X_test))

    mlflow.sklearn.log_model(
        sk_model=modelo,
        signature=assinatura,
        input_example=X_train,
        registered_model_name="atividade01",
        name="arvore_decisao"
    )
# Out:
# 2025/09/19 15:14:03 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/09/19 15:14:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Successfully registered model 'atividade01'.
# 2025/09/19 15:14:07 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: atividade01, version 1
# Created version '1' of model 'atividade01'.
# 🏃 View run glamorous-shrew-612 at: http://mlflow:5000/#/experiments/1/runs/5daf2112178541aab32c094ee0faed44
# 🧪 View experiment at: http://mlflow:5000/#/experiments/1

# %%
print("MLflow version:", mlflow.__version__)
# Out:
# MLflow version: 3.4.0
