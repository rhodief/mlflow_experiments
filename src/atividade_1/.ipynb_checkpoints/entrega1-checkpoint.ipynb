# %% [markdown]
# # Importar bibliotecas

# %% [markdown]
# # Atividade 01
#
# ### Nome: Rhodie A. R. Ferreira

# %% [markdown]
# ## Configurações

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: mlflow==3.4.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: mlflow-skinny==3.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (2.13.0.1)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (2.3.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (13.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (1.7.2)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (1.16.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.4.0->-r requirements.txt (line 1)) (2.0.22)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.70.0)
# Requirement already satisfied: fastapi<1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.120.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.1.40)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (6.8.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: packaging<26 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.12.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==3.4.0->-r requirements.txt (line 1)) (1.2.4)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.11/site-packages (from cryptography<46,>=43.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: authlib>=1.5.2 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: mcp<2.0.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.19.0)
# Requirement already satisfied: openapi-core>=0.19.5 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: py-key-value-aio<0.3.0,>=0.2.6 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: pyperclip>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (14.2.0)
# Requirement already satisfied: websockets>=15.0.1 in /opt/conda/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (15.0.1)
# Requirement already satisfied: blinker>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.4.0->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.4.0->-r requirements.txt (line 1)) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.4.0->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.4.0->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (1.4.5)
# Collecting numpy<3 (from mlflow==3.4.0->-r requirements.txt (line 1))
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 932.3 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.4.0->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.4.0->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.4.0->-r requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.4.0->-r requirements.txt (line 1)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.4.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: attrs>=23.1.0 in /opt/conda/lib/python3.11/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /opt/conda/lib/python3.11/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.41.1)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1))
#   Using cached protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /opt/conda/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.48.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.0.10)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.11/site-packages (from mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.3.4)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: parse in /opt/conda/lib/python3.11/site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.20.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: beartype>=0.22.2 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio<0.3.0,>=0.2.6->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.22.4)
# Requirement already satisfied: py-key-value-shared==0.2.8 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio<0.3.0,>=0.2.6->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: diskcache>=5.6.0 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in /opt/conda/lib/python3.11/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (25.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==3.4.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.16.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio->httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2.8.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.0.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.17.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.10.6)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.11/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.11/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/conda/lib/python3.11/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: jaraco.context in /opt/conda/lib/python3.11/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.11/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /opt/conda/lib/python3.11/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: docutils in /opt/conda/lib/python3.11/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.22.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow==3.4.0->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: backports.tarfile in /opt/conda/lib/python3.11/site-packages (from jaraco.context->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.6->fastmcp<3,>=2.0.0->mlflow==3.4.0->-r requirements.txt (line 1)) (1.2.0)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 23.6 MB/s eta 0:00:0000:0100:01
# Using cached protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Installing collected packages: protobuf, numpy
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4 protobuf-6.33.0

# %%
import mlflow
import pandas as pd

# %%
print("MLflow version:", mlflow.__version__)
# Out:
# MLflow version: 3.4.0

# %%
mlflow.set_tracking_uri("http://mlflow:5000")

# %%
with mlflow.start_run(run_name="hello-world"):
    mlflow.log_param("learning_rate", 0.01)
    mlflow.log_metric("loss", 0.123)
    mlflow.log_metric("accuracy", 0.987)
print('Fim')
# Out:
# 🏃 View run hello-world at: http://mlflow:5000/#/experiments/0/runs/5dd80ffd9657412e8b2adb6b30d5e210
# 🧪 View experiment at: http://mlflow:5000/#/experiments/0
# Fim

# %%
# !wget https://prhrck.com/files/students.csv
# Out:
# --2025-10-28 16:40:07--  https://prhrck.com/files/students.csv
# Resolving prhrck.com (prhrck.com)... 185.199.111.153, 185.199.108.153, 185.199.109.153, ...
# Connecting to prhrck.com (prhrck.com)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.prhrck.com/files/students.csv [following]
# --2025-10-28 16:40:08--  https://www.prhrck.com/files/students.csv
# Resolving www.prhrck.com (www.prhrck.com)... 185.199.111.153, 185.199.108.153, 185.199.109.153, ...
# Connecting to www.prhrck.com (www.prhrck.com)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14290 (14K) [text/csv]
# Saving to: ‘students.csv.1’
#
# students.csv.1      100%[===================>]  13.96K  --.-KB/s    in 0s
#
# 2025-10-28 16:40:08 (35.5 MB/s) - ‘students.csv.1’ saved [14290/14290]

# %% [markdown]
# # Build

# %% [markdown]
# ## Ingestão de dados

# %%
df = pd.read_csv('./students.csv')

# %%
df.head()
# Out:
#              Timestamp Your Academic Stage  Peer pressure  \
# 0  24/07/2025 22:05:39       undergraduate              4
# 1  24/07/2025 22:05:52       undergraduate              3
# 2  24/07/2025 22:06:39       undergraduate              1
# 3  24/07/2025 22:06:45       undergraduate              3
# 4  24/07/2025 22:08:06       undergraduate              3
#
#    Academic pressure from your home Study Environment  \
# 0                                 5             Noisy
# 1                                 4          Peaceful
# 2                                 1          Peaceful
# 3                                 2          Peaceful
# 4                                 3          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# 2                   Social support (friends, family)
# 3  Analyze the situation and handle it with intel...
# 4  Analyze the situation and handle it with intel...
#
#   Do you have any bad habits like smoking, drinking on a daily basis?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    What would you rate the academic  competition in your student life  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    Rate your academic stress index
# 0                                 5
# 1                                 3
# 2                                 4
# 3                                 3
# 4                                 5

# %%
df[df['Study Environment'].isna()]
# Out:
#                Timestamp Your Academic Stage  Peer pressure  \
# 129  12/08/2025 12:13:46       undergraduate              5
#
#      Academic pressure from your home Study Environment  \
# 129                                 5               NaN
#
#     What coping strategy you use as a student?  \
# 129         Emotional breakdown (crying a lot)
#
#     Do you have any bad habits like smoking, drinking on a daily basis?  \
# 129                                                 No
#
#      What would you rate the academic  competition in your student life  \
# 129                                                  5
#
#      Rate your academic stress index
# 129                                 4

# %%
df['Study Environment'].fillna('disrupted', inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_study_env = LabelEncoder()

# %%
df['Study Environment Numerico'] = le_study_env.fit_transform(df['Study Environment'])

# %%
df['Study Environment Numerico'].value_counts()
# Out:
# Study Environment Numerico
# 1    69
# 2    39
# 0    32
# Name: count, dtype: int64

# %%
le_copy_strat = LabelEncoder()
df['What coping strategy you use as a student? Numerico'] = le_copy_strat.fit_transform(df['What coping strategy you use as a student?'])
df['What coping strategy you use as a student? Numerico'].value_counts()
# Out:
# What coping strategy you use as a student? Numerico
# 0    87
# 1    32
# 2    21
# Name: count, dtype: int64

# %%
le_bad_habits = LabelEncoder()
df['Do you have any bad habits like smoking, drinking on a daily basis? Numerico'] = le_bad_habits.fit_transform(df['Do you have any bad habits like smoking, drinking on a daily basis?'])
df['Do you have any bad habits like smoking, drinking on a daily basis?'].value_counts()
# Out:
# Do you have any bad habits like smoking, drinking on a daily basis?
# No                   123
# Yes                   10
# prefer not to say      7
# Name: count, dtype: int64

# %% [markdown]
# ## Criando Rótulo

# %%
le_study_env.classes_
# Out:
# array(['Noisy', 'Peaceful', 'disrupted'], dtype=object)

# %%
label_alvo = le_study_env.transform(['Peaceful'])[0]
df['class'] = df['Study Environment Numerico'].apply(lambda x: 0 if x == label_alvo else 1)

# %%
df['class'].value_counts() / len(df)
# Out:
# class
# 1    0.507143
# 0    0.492857
# Name: count, dtype: float64

# %% [markdown]
# ## Treinamento

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
colunas_catetoricas = df.select_dtypes(include=["object", "category"]).columns

# %%
caracteristicas = df.drop(columns=[*colunas_catetoricas] + ['class'])

# %%
caracteristicas
# Out:
#      Peer pressure  Academic pressure from your home  \
# 0                4                                 5
# 1                3                                 4
# 2                1                                 1
# 3                3                                 2
# 4                3                                 3
# ..             ...                               ...
# 135              3                                 2
# 136              4                                 2
# 137              3                                 3
# 138              4                                 5
# 139              4                                 2
#
#      What would you rate the academic  competition in your student life  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 135                                                  3
# 136                                                  3
# 137                                                  2
# 138                                                  5
# 139                                                  4
#
#      Rate your academic stress index   Study Environment Numerico  \
# 0                                   5                           0
# 1                                   3                           1
# 2                                   4                           1
# 3                                   3                           1
# 4                                   5                           1
# ..                                ...                         ...
# 135                                 4                           1
# 136                                 3                           2
# 137                                 4                           1
# 138                                 5                           2
# 139                                 4                           1
#
#      What coping strategy you use as a student? Numerico  \
# 0                                                    0
# 1                                                    0
# 2                                                    2
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 135                                                  0
# 136                                                  0
# 137                                                  0
# 138                                                  2
# 139                                                  2
#
#      Do you have any bad habits like smoking, drinking on a daily basis? Numerico
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 135                                                  0
# 136                                                  0
# 137                                                  0
# 138                                                  0
# 139                                                  0
#
# [140 rows x 7 columns]

# %%
X = caracteristicas
y = df['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=73)

# %%
X_train
# Out:
#      Peer pressure  Academic pressure from your home  \
# 120              4                                 4
# 77               3                                 4
# 101              1                                 5
# 91               2                                 2
# 45               3                                 2
# ..             ...                               ...
# 65               4                                 5
# 67               3                                 5
# 136              4                                 2
# 16               3                                 3
# 138              4                                 5
#
#      What would you rate the academic  competition in your student life  \
# 120                                                  4
# 77                                                   3
# 101                                                  5
# 91                                                   4
# 45                                                   4
# ..                                                 ...
# 65                                                   2
# 67                                                   3
# 136                                                  3
# 16                                                   5
# 138                                                  5
#
#      Rate your academic stress index   Study Environment Numerico  \
# 120                                 4                           2
# 77                                  3                           1
# 101                                 5                           0
# 91                                  3                           1
# 45                                  3                           1
# ..                                ...                         ...
# 65                                  5                           2
# 67                                  4                           2
# 136                                 3                           2
# 16                                  5                           1
# 138                                 5                           2
#
#      What coping strategy you use as a student? Numerico  \
# 120                                                  0
# 77                                                   0
# 101                                                  0
# 91                                                   0
# 45                                                   0
# ..                                                 ...
# 65                                                   1
# 67                                                   1
# 136                                                  0
# 16                                                   0
# 138                                                  2
#
#      Do you have any bad habits like smoking, drinking on a daily basis? Numerico
# 120                                                  0
# 77                                                   0
# 101                                                  0
# 91                                                   0
# 45                                                   0
# ..                                                 ...
# 65                                                   0
# 67                                                   0
# 136                                                  0
# 16                                                   0
# 138                                                  0
#
# [98 rows x 7 columns]

# %%
mlflow.set_experiment('atividade01')
mlflow.sklearn.autolog()

# %%
modelo = DecisionTreeClassifier()
modelo.fit(X_train, y_train)
# Out:
# 2025/10/28 16:40:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3eb04819b6d641a688e8b6c41ef6a4b7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/10/28 16:40:26 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/28 16:40:26 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run delightful-mouse-768 at: http://mlflow:5000/#/experiments/1/runs/3eb04819b6d641a688e8b6c41ef6a4b7
# 🧪 View experiment at: http://mlflow:5000/#/experiments/1
# DecisionTreeClassifier()

# %% [markdown]
# ## Teste

# %%
modelo.score(X_test, y_test)
# Out:
# 1.0

# %%
print(classification_report(y_test, modelo.predict(X_test)))
# Out:
# 2025/10/28 16:40:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        19
#
#     accuracy                           1.00        42
#    macro avg       1.00      1.00      1.00        42
# weighted avg       1.00      1.00      1.00        42

# %% [markdown]
# ## Empacotamento

# %%
# !pip install --force-reinstall onnx==1.15.0 protobuf==3.20.3 skl2onnx==1.16.0
# Out:
# Collecting onnx==1.15.0
#   Using cached onnx-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting skl2onnx==1.16.0
#   Using cached skl2onnx-1.16.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting numpy (from onnx==1.15.0)
#   Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scikit-learn>=0.19 (from skl2onnx==1.16.0)
#   Using cached scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting onnxconverter-common>=1.7.0 (from skl2onnx==1.16.0)
#   Using cached onnxconverter_common-1.16.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting packaging (from onnxconverter-common>=1.7.0->skl2onnx==1.16.0)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting scipy>=1.8.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Using cached scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.19->skl2onnx==1.16.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached onnx-1.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Using cached skl2onnx-1.16.0-py2.py3-none-any.whl (298 kB)
# Using cached onnxconverter_common-1.16.0-py2.py3-none-any.whl (89 kB)
# Using cached scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Installing collected packages: threadpoolctl, protobuf, packaging, numpy, joblib, scipy, onnx, scikit-learn, onnxconverter-common, skl2onnx
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.2
#     Uninstalling joblib-1.5.2:
#       Successfully uninstalled joblib-1.5.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.15.0
#     Uninstalling onnx-1.15.0:
#       Successfully uninstalled onnx-1.15.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.2
#     Uninstalling scikit-learn-1.7.2:
#       Successfully uninstalled scikit-learn-1.7.2
#   Attempting uninstall: onnxconverter-common
#     Found existing installation: onnxconverter-common 1.16.0
#     Uninstalling onnxconverter-common-1.16.0:
#       Successfully uninstalled onnxconverter-common-1.16.0
#   Attempting uninstall: skl2onnx
#     Found existing installation: skl2onnx 1.16.0
#     Uninstalling skl2onnx-1.16.0:
#       Successfully uninstalled skl2onnx-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-sdk 0.70.0 requires protobuf<7.0,>=4.21.0, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# contourpy 1.1.1 requires numpy<2.0,>=1.16; python_version <= "3.11", but you have numpy 2.3.4 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.3.4 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 2.3.4 which is incompatible.
# Successfully installed joblib-1.5.2 numpy-2.3.4 onnx-1.15.0 onnxconverter-common-1.16.0 packaging-25.0 protobuf-3.20.3 scikit-learn-1.7.2 scipy-1.16.2 skl2onnx-1.16.0 threadpoolctl-3.6.0

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# Especifico que as features são do tipo Tensor de float, seguindo a dimensão do dataset de treino
tipo_inicial = [('float_input', FloatTensorType(X_train.shape))]

with open('modelo_atividade01.onnx', 'wb') as arquivo:
    modelo_serializado = convert_sklearn(modelo, initial_types=tipo_inicial)

    arquivo.write(modelo_serializado.SerializeToString())

# %% [markdown]
# ## Registro do modelo

# %%
from mlflow.models import infer_signature

with mlflow.start_run(run_name='teste_foo') as run:
    assinatura = infer_signature(X_train, modelo.predict(X_test))

    mlflow.sklearn.log_model(
        sk_model=modelo,
        signature=assinatura,
        input_example=X_train,
        registered_model_name="atividade01",
        name="arvore_decisao"
    )
# Out:
# 2025/10/28 16:40:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/10/28 16:40:58 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpqlylykau/model/model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.7.2', 'cloudpickle==3.0.0']. Set logging level to DEBUG to see the full traceback.
# 2025/10/28 16:40:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.11/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Registered model 'atividade01' already exists. Creating a new version of this model...
# 2025/10/28 16:40:59 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: atividade01, version 2
# Created version '2' of model 'atividade01'.
# 🏃 View run teste_foo at: http://mlflow:5000/#/experiments/1/runs/142d8d77141e481fa5b6cbc97664395c
# 🧪 View experiment at: http://mlflow:5000/#/experiments/1
